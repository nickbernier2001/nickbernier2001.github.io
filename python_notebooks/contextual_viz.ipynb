# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import altair as alt
import ipywidgets

# %%
df = pd.read_csv('Census_Data_-_Languages_spoken_in_Chicago__2008___2012.csv')
df
# Out:
#     Community Area Community Area Name PREDOMINANT NON-ENGLISH LANGUAGE (%)  \
# 0                1         Rogers Park                       SPANISH (9.9%)
# 1                2          West Ridge                       SPANISH (8.7%)
# 2                3              Uptown                       SPANISH (4.9%)
# 3                4      Lincoln Square                       SPANISH (8.4%)
# 4                5        North Center                       SPANISH (4.2%)
# ..             ...                 ...                                  ...
# 73              74     Mount Greenwood                       SPANISH (0.5%)
# 74              75         Morgan Park                       SPANISH (0.6%)
# 75              76              O'Hare                       POLISH (11.8%)
# 76              77           Edgewater                       SPANISH (4.6%)
# 77               0             Chicago                      SPANISH (11.3%)
#
# ...

# %%
columns = df['Community Area Name'].values.tolist()
columns.remove('Chicago')
languages = df.columns.tolist()
languages.remove('Community Area')
languages.remove('Community Area Name')
languages.remove('PREDOMINANT NON-ENGLISH LANGUAGE (%)')

@ipywidgets.interact(CommunityName = columns)
def make_bar_plot(CommunityName):
    x = languages
    y = df[df['Community Area Name'] == CommunityName][languages].values[0]
    plt.xticks(rotation = 90)
    plt.tick_params(axis='x', labelsize=8)
    plt.title(CommunityName)
    plt.xlabel('Language')
    plt.ylabel('Number of Speakers')
    plt.bar(x, y)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='CommunityName', options=('Rogers Park', 'West Ridge', 'Uptown', 'L…
